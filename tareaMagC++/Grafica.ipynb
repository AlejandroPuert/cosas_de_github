# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Uakata = np.loadtxt('difusion.txt')

# %%
n = 100
x = np.linspace(0,6,19)
plt.plot(x,Uakata[n])


t = n*(10/100)# T=10; Nt = 100
plt.grid()
plt.title("U(x) para el tiempo t = %s" % t )
plt.xlabel("distribución lineal [0,L]")
plt.ylabel("Concentración del material [unidades :)]")
# Out:
# Text(0, 0.5, 'Concentración del material [unidades :)]')
